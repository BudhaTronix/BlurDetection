# %%
import sys
sys.path.insert(1, '/project/mukhopad/tmp/BlurDetection_tmp/codes/Utils/')
from testingScript import TestingScript

# %%
Test = TestingScript()

# %%
Test.main()
# Out:
# Creation of temporary directory /project/mukhopad/tmp/BlurDetection_tmp/Dataset/temp/tmp/ failed
#  CSV File missing..
# Generating new CVS File..
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 658/658 [00:00<00:00, 111843.57it/s]
#  CSV File Created!
# Model In Testing mode
# FileName:  IXI662-Guys-1120-T1-0_0.nii.gz --  Model OP->  0.19496412575244904
# FileName:  IXI662-Guys-1120-T1-0_1.nii.gz --  Model OP->  0.21978530287742615
# FileName:  IXI662-Guys-1120-T1-0_10.nii.gz --  Model OP->  0.22506403923034668
# FileName:  IXI662-Guys-1120-T1-0_100.nii.gz --  Model OP->  0.47684988379478455
# FileName:  IXI662-Guys-1120-T1-0_101.nii.gz --  Model OP->  0.4966650903224945
# FileName:  IXI662-Guys-1120-T1-0_102.nii.gz --  Model OP->  0.494428426027298
# FileName:  IXI662-Guys-1120-T1-0_103.nii.gz --  Model OP->  0.47924232482910156
# FileName:  IXI662-Guys-1120-T1-0_104.nii.gz --  Model OP->  0.49782636761665344
# ...

# %%
import nibabel as nib
example_filename = "/project/mukhopad/tmp/BlurDetection_tmp/Dataset/temp/tmp/IXI662-Guys-1120-T1-1_202.nii.gz"
img = nib.load(example_filename)
data = img.get_fdata()

# %%
img.shape
# Out:
# (239, 180)
